# %% [markdown]
# Ex 1

# %%
class Song():
    def __init__(self, titol, autor, durada):
        self.titol = titol
        self.autor = autor
        self.durada = durada

    def info(self):
        return f"{self.titol} - {self.autor} ({self.durada} segons)"
        
        

class Playlist():
    def __init__(self, song_lista):
        self.song_lista = song_lista

    def afegir_canco(self, song):
        self.song_lista.append(song)

    def durada_total(self):
        duradamesgran = 0
        for i in self.song_lista:
            duradamesgran += i.durada

        

        print(duradamesgran)

    def cancollarga(self):
        mesgran = 0
        vencedor = ""
        for i in self.song_lista:
            if i.durada > mesgran:
                mesgran = i.durada
                vencedor = i
                
        
    def mostrar_playlist(self):
        for i in self.song_lista:
            print(i.info())
            
print(vencedor.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 41
#      38         for i in self.song_lista:
#      39             print(i.info())
# ---> 41 print(vencedor.info())
#
# NameError: name 'vencedor' is not defined

# %%
canco1 = Song("Thunder", "Imagin Dragons", 184)
canco2 = Song("Drac magic", "cancons de nens", 250)

play1 = Playlist([])

canco3 = Song("Paambtomaquet", "Nil", 90)

play1.afegir_canco(canco1)
play1.afegir_canco(canco2)


play1.afegir_canco(canco3)

play1.mostrar_playlist()
play1.durada_total()
play1.cancollarga()
# Out:
# Thunder - Imagin Dragons (184 segons)
# Drac magic - cancons de nens (250 segons)
# Paambtomaquet - Nil (90 segons)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 15
#      12 play1.afegir_canco(canco3)
#      14 play1.mostrar_playlist()
# ---> 15 play1.durada_total()
#      16 play1.cancollarga()
#
# Cell In[17], line 24, in Playlist.durada_total(self)
#      21 for i in self.song_lista:
#      22     duradamesgran += i.durada
# ---> 24 print(vencedor.info())
#      26 print(duradamesgran)
#
# NameError: name 'vencedor' is not defined

# %% [markdown]
# Execisi 2

# %%
class Personatge:
    def init(self, nom, força, vida, nivell):
        self.nom = nom
        self.força = força
        self.vida = vida
        self.nivell = nivell

    def atacar(self, enemic):
        if enemic.vida <= self.força:
            enemic.vida = 0

    def pujarnivell(self):
        self.nivell += 1
        self.força += 2
        self.vida += 5

    def str(self):
        return f"Personatge: {self.nom}, Força: {self.força}, Vida: {self.vida}"

if self.nom == "personatge":
    hero = Personatge("Hero", 10, 100, 1)
    monstre = Personatge("Monstre", 7, 80, 1)

while hero.vida > 0 and monstre.vida > 0:
        hero.atacar(monstre)
        if monstre.vida > 0:
            monstre.atacar(hero)
        print("Saguim en peu")

if hero.vida <= 0 or monstre.vida <= 0:
    print("Fi del combat!")
    if hero.vida <= 0:
        print(f"{hero.nom} ha estat derrotat.")
    else:
        print(f"{monstre.nom} ha estat derrotat.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 20
#      17     def str(self):
#      18         return f"Personatge: {self.nom}, Força: {self.força}, Vida: {self.vida}"
# ---> 20 if self.nom == "personatge":
#      21     hero = Personatge("Hero", 10, 100, 1)
#      22     monstre = Personatge("Monstre", 7, 80, 1)
#
# NameError: name 'self' is not defined
